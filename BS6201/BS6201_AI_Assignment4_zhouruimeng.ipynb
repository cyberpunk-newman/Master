# %% [markdown]
# Explore white wine dataset, follow what we did with red wine data:
#
#     share 2 observations within the dataset (white wine itself)
#     share 2 observations across the two datasets (red vs white wine dataset)
#
# Bonus:
#
#     Use other kinds of visualization apart from boxplot
#     Feel free to come up with a data story. Something you'd like to share about the dataset / interesting observation

# %% [markdown]
# ##  Queation 1:
# we can see there are 4898 rows which means we have 4898 observations, so I share the first one and last one.

# %%
import pandas as pd

df_white = pd.read_csv(r"D:/PG_study/BS6201/week4/winequality-white.csv",sep = ';')
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# ## Queation 2:
# we can see there are 3 rows which means we have 3 observations across white wine and red wine.

# %%
df_red = pd.read_csv(r"D:/PG_study/BS6201/week4/winequality-red.csv",sep = ';')

df_intersect = pd.merge(df_red,df_white, how = 'inner' ,indicator=False)
df_intersect
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            6.7              0.28         0.28             2.4      0.012
# 1            6.7              0.28         0.28             2.4      0.012
# 2            5.9              0.19         0.21             1.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 36.0                 100.0  0.99064  3.26       0.39
# 1                 36.0                 100.0  0.99064  3.26       0.39
# 2                 57.0                 135.0  0.99341  3.32       0.44
#
#    alcohol  quality
# 0     11.7        7
# 1     11.7        7
# 2      9.5        5

# %% [markdown]
# ## Bonus ：
# I compare the residual sugar between white wine and red wine because fermentation is one of the ways to make wine and using residual sugar we can divide wines into dry wines or other kinds. I order the level from large to small, and found that red wine are lower than white wine in general. That's why most of time red wine will tastes more bitter than white wine.
#
# And we can see nearly 1150 white wines are higher than 10 and only 10 red wines are higher than 10. So we can calculate about 23.48% in white wine are dry wine and only 0.6% of red wine is dry wine.

# %%
import seaborn as sns
import numpy as np
from numpy.random import randn
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy import stats

 
x = df_white.iloc[:,3] #the residual sugar value
y = df_red.iloc[:,3] #the residual sugar value

x = sorted(x,reverse=True)
y = sorted(y,reverse=True)
#print(len(y))

plt.figure(figsize=(10,6))
plt.plot(x[0:1599],label = 'white wine')
plt.plot(y[0:1599],label = 'red wine')
plt.xlabel('Observations')
plt.ylabel('Residual Sugar')
plt.grid(linestyle='-.')
plt.legend(fontsize='16')
plt.title("Top 1600 Observatoins")
# Out:
# Text(0.5, 1.0, 'Top 1600 Observatoins')

# %%
plt.figure(figsize=(10,6))
plt.plot(x[0:50],label = 'white wine')
plt.plot(y[0:50],label = 'red wine')
plt.xlabel('Observations')
plt.ylabel('Residual Sugar')
plt.grid(linestyle='-.')
plt.legend(fontsize='16')
plt.title("Top 50 Observatoins")
# Out:
# Text(0.5, 1.0, 'Top 50 Observatoins')
